# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
# Out:
# D:\ProgramData\Anaconda3\envs\tenserflow\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston_df = DataFrame(boston.data)

boston_df.columns = boston.feature_names

boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_df['price'] = boston.target

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
boston_df['price']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: price, Length: 506, dtype: float64

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
total_dr = boston_df['AGE']
sns.set_style(style='whitegrid')
fig_dims = (10,5)
fig, ax = plt.subplots(figsize=fig_dims)
ax = sns.lineplot(x=boston_df['price'], y = total_dr, ax=ax).set(title='Year vs Duration')
plt.xticks(rotation=60)
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(boston_df.corr(), annot=True, linewidths=0.4,linecolor="white", fmt= '.1f',ax=ax,cmap="Blues")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=boston_df, y = 'RAD', x = 'TAX', color='c').set(title='Tax vs Index of accessibility to radial highways')
# Out:
# [Text(0.5, 1.0, 'Tax vs Index of accessibility to radial highways')]

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # FOr the linear Regrission we do have the formula y = mX+B

# %%
X=boston_df.RM

# %%
X
# Out:
# 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 501    6.593
# 502    6.120
# 503    6.976
# 504    6.794
# 505    6.030
# Name: RM, Length: 506, dtype: float64

# %%
X.shape
# Out:
# (506,)

# %%
#To fit the value of the X we need to convert the shape into (value,2) which is 2D
X = np.vstack(boston_df.RM)

# %%
X = boston_df.RM

X=np.vstack([boston_df.RM,np.ones(len(boston_df.RM))]).T

Y = boston_df.price

m,b = np.linalg.lstsq(X,Y)[0]

print(m, b)

plt.plot(boston_df.RM,boston_df.price,'o')

x= boston_df.RM

plt.plot(x, m*x + b,'r',label='Best Fit Line')
# Out:
# 9.102108981180313 -34.67062077643856
# C:\Users\ibrah\AppData\Local\Temp/ipykernel_18276/795077026.py:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,b = np.linalg.lstsq(X,Y)[0]

# %%
#performing the same above steps using the seaborn regression plot
plt.figure(figsize=(10,6))
sns.regplot(data=boston_df, y = 'price', x = 'RM', color='c').set(title='Tax vs Index of accessibility to radial highways')
# Out:
# [Text(0.5, 1.0, 'Tax vs Index of accessibility to radial highways')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data = boston_df,y = 'AGE',  x='price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='AGE'>

# %%
plt.figure(figsize=(10,6))

sns.lmplot('RM','price',data = boston_df)
# Out:
# D:\ProgramData\Anaconda3\envs\tenserflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
lreg = LinearRegression()

# %%
X_multi = boston_df.drop('price',1)
Y_target = boston_df.price
# Out:
# C:\Users\ibrah\AppData\Local\Temp/ipykernel_18276/3597228533.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X_multi = boston_df.drop('price',1)

# %%
lreg.fit(X_multi,Y_target)
# Out:
# LinearRegression()

# %%
print('The estimated intercept coefficient is %.2f' %lreg.intercept_)
print('The number of coefficient used was %d' %len(lreg.coef_))
# Out:
# The estimated intercept coefficient is 36.46
# The number of coefficient used was 13

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
coeff_df = DataFrame(boston_df.columns)
coeff_df.columns=['features']

coeff_df['Coefficient Estimator'] = Series(lreg.coef_)
coeff_df
# Out:
#    features  Coefficient Estimator
# 0      CRIM              -0.108011
# 1        ZN               0.046420
# 2     INDUS               0.020559
# 3      CHAS               2.686734
# 4       NOX             -17.766611
# 5        RM               3.809865
# 6       AGE               0.000692
# 7       DIS              -1.475567
# 8       RAD               0.306049
# 9       TAX              -0.012335
# 10  PTRATIO              -0.952747
# 11        B               0.009312
# 12    LSTAT              -0.524758
# 13    price                    NaN

# %%
coeff_df.nlargest(10,'Coefficient Estimator')
# Out:
#    features  Coefficient Estimator
# 5        RM               3.809865
# 3      CHAS               2.686734
# 8       RAD               0.306049
# 1        ZN               0.046420
# 2     INDUS               0.020559
# 11        B               0.009312
# 6       AGE               0.000692
# 9       TAX              -0.012335
# 0      CRIM              -0.108011
# 12    LSTAT              -0.524758

# %%
boston_df['price']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: price, Length: 506, dtype: float64

# %%
X_train,X_test,Y_train,Y_test = sklearn.model_selection.train_test_split(X,boston_df.price)

# %%
lreg = LinearRegression()
lreg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred_train = lreg.predict(X_train)
pred_test = lreg.predict(X_test)

# %%
print('Fit a model X train and calcluate the MSE with Y train %2.f' %np.mean((Y_train-pred_train)**2))
# Out:
# Fit a model X train and calcluate the MSE with Y train 44

# %%
print('Fit a model X test and calcluate the MSE with Y test %2.f' %np.mean((Y_test-pred_test)**2))
# Out:
# Fit a model X test and calcluate the MSE with Y test 42

# %%
train = plt.scatter(pred_train,(pred_train-Y_train),c='b',alpha=0.5)
test = plt.scatter(pred_test,(pred_test-Y_test),c='r',alpha=0.5)
plt.hlines(y=0,xmin=-10,xmax=40)
plt.legend((train,test),('Training','Test'),loc='lower left')
plt.title('Residual Plot')
# Out:
# Text(0.5, 1.0, 'Residual Plot')
